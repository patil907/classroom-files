# %% [markdown]
# # Why to visualize data?
# - Data visualization is the practice of translating information into a visual context, such as a map or graph, to make data easier for the human brain to understand and pull insights from. The main goal of data visualization is to make it easier to identify patterns, trends and outliers in large data sets.
#     - Better analysis
#     - Quick action
#     - Identifying patterns
#     - Finding errors
#     - Understanding the story
#     - Exploring business insights
#     - Grasping the Latest Trends
#
# # What is Matplotlib?
#
# - Matplotlib is a python visualisation library, majorly used for plotting 2D data.
# - Matplotlib is a multi-platform data visualization library built on NumPy arrays and designed to work with the broader SciPy stack.
# - Matplotlib consists of several plots like line, bar, scatter, histogram etc.

# %%
##Import library
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # **Matplotlib Line plot**

# %%
x = np.linspace(1,20,25)
y = np.random.random_sample(25)
x
# Out:
# array([ 1.        ,  1.79166667,  2.58333333,  3.375     ,  4.16666667,
#         4.95833333,  5.75      ,  6.54166667,  7.33333333,  8.125     ,
#         8.91666667,  9.70833333, 10.5       , 11.29166667, 12.08333333,
#        12.875     , 13.66666667, 14.45833333, 15.25      , 16.04166667,
#        16.83333333, 17.625     , 18.41666667, 19.20833333, 20.        ])

# %%
y
# Out:
# array([0.80117193, 0.09809394, 0.54981847, 0.25358946, 0.5688117 ,
#        0.15372734, 0.88708081, 0.45754462, 0.50348001, 0.73131356,
#        0.26267739, 0.40675378, 0.25234754, 0.28490916, 0.93772079,
#        0.60184483, 0.66613259, 0.62498864, 0.98073234, 0.28555745,
#        0.96021646, 0.98515174, 0.58507115, 0.46236591, 0.99636702])

# %%
plt.plot(x,y)

# %%
plt.figure(figsize=(10,5)) #Changes the size of the graph.(Temporary changes)
plt.plot(x,y)

# %%
plt.plot(x,y)

# %%
#Set graph parameters
plt.rcParams['figure.figsize'] = (10,5) #Increases size of graph
plt.rcParams['figure.dpi'] = 250 # Used to increase pixels of images

# %%
plt.plot(x,y,linestyle = 'dashdot', color = 'red')
plt.grid()

# %% [markdown]
# # Matplotlib Histogram
# - A histogram is a graph showing frequency distributions.
#
# - It is a graph showing the number of observations within each given interval.

# %%
#Read external file
df = pd.read_csv('https://raw.githubusercontent.com/aishwaryamate/Datasets/main/cars.csv')
df
# Out:
#      symboling normalized-losses         make fuel-type   body-style  \
# 0            3                 ?  alfa-romero       gas  convertible
# 1            3                 ?  alfa-romero       gas  convertible
# 2            1                 ?  alfa-romero       gas    hatchback
# 3            2               164         audi       gas        sedan
# 4            2               164         audi       gas        sedan
# ..         ...               ...          ...       ...          ...
# 200         -1                95        volvo       gas        sedan
# 201         -1                95        volvo       gas        sedan
# 202         -1                95        volvo       gas        sedan
# 203         -1                95        volvo    diesel        sedan
# 204         -1                95        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# 0            rwd           front   64.1    48.8        dohc          130
# 1            rwd           front   64.1    48.8        dohc          130
# 2            rwd           front   65.5    52.4        ohcv          152
# 3            fwd           front   66.2    54.3         ohc          109
# 4            4wd           front   66.4    54.3         ohc          136
# ..           ...             ...    ...     ...         ...          ...
# 200          rwd           front   68.9    55.5         ohc          141
# 201          rwd           front   68.8    55.5         ohc          141
# 202          rwd           front   68.9    55.5        ohcv          173
# 203          rwd           front   68.9    55.5         ohc          145
# 204          rwd           front   68.9    55.5         ohc          141
#
#     horsepower  city-mpg  highway-mpg  price
# 0          111        21           27  13495
# 1          111        21           27  16500
# 2          154        19           26  16500
# 3          102        24           30  13950
# 4          115        18           22  17450
# ..         ...       ...          ...    ...
# 200        114        23           28  16845
# 201        160        19           25  19045
# 202        134        18           23  21485
# 203        106        26           27  22470
# 204        114        19           25  22625
#
# [205 rows x 15 columns]

# %%
plt.hist(df['width'])
# Out:
# (array([ 1.,  2., 36., 39., 44., 42., 20.,  7.,  6.,  8.]),
#  array([60.3, 61.5, 62.7, 63.9, 65.1, 66.3, 67.5, 68.7, 69.9, 71.1, 72.3]),
#  <BarContainer object of 10 artists>)

# %%
df['width'].skew()
# Out:
# 0.904003498786254

# %%
df.hist()
plt.tight_layout()

# %%
#median and mean

# %%
mean = df['width'].mean()
median = df['width'].median()
mean,median
# Out:
# (65.90780487804875, 65.5)

# %%
plt.hist(df['width'],edgecolor = 'black')
plt.axvline(mean, color = 'red')
plt.axvline(median, color = 'green')
plt.title('Frequency graph for width column', size = 25)
plt.xlabel('Width Values')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# # SEABORN

# %% [markdown]
# **COUNTPLOT**

# %%
import seaborn as sns

# %%
df['body-style'].value_counts()
# Out:
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: body-style, dtype: int64

# %%
sns.countplot(x = df['body-style'])
# Out:
# <AxesSubplot:xlabel='body-style', ylabel='count'>

# %%
import warnings #Used to hide the warning messages in jupyter notebook 
warnings.filterwarnings('ignore')

# %%
sns.countplot(x = df['make'])
# Out:
# <AxesSubplot:xlabel='make', ylabel='count'>

# %%
sns.countplot(y = df['make'])
# Out:
# <AxesSubplot:xlabel='count', ylabel='make'>

# %%
sns.countplot(x = df['make'])
plt.xticks(rotation = 90)
plt.show()

# %%
#Pandas barplot

# %%
df['body-style'].value_counts()
# Out:
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: body-style, dtype: int64

# %%
plt.rcParams['figure.figsize'] = (10,5)
plt.rcParams['figure.dpi'] = 250
sns.set_theme(style='darkgrid',palette='viridis') #Used for styling purpose

# %%
df['body-style'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Pandas piechart

# %%
a = [20,30,25,36] #Frequency
b = ['a','b','c','d'] #Labels

# %%
plt.pie(a,labels = b, autopct='%0.0f%%')
plt.show()

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type   body-style  \
# 0            3                 ?  alfa-romero       gas  convertible
# 1            3                 ?  alfa-romero       gas  convertible
# 2            1                 ?  alfa-romero       gas    hatchback
# 3            2               164         audi       gas        sedan
# 4            2               164         audi       gas        sedan
# ..         ...               ...          ...       ...          ...
# 200         -1                95        volvo       gas        sedan
# 201         -1                95        volvo       gas        sedan
# 202         -1                95        volvo       gas        sedan
# 203         -1                95        volvo    diesel        sedan
# 204         -1                95        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# 0            rwd           front   64.1    48.8        dohc          130
# 1            rwd           front   64.1    48.8        dohc          130
# 2            rwd           front   65.5    52.4        ohcv          152
# 3            fwd           front   66.2    54.3         ohc          109
# 4            4wd           front   66.4    54.3         ohc          136
# ..           ...             ...    ...     ...         ...          ...
# 200          rwd           front   68.9    55.5         ohc          141
# 201          rwd           front   68.8    55.5         ohc          141
# 202          rwd           front   68.9    55.5        ohcv          173
# 203          rwd           front   68.9    55.5         ohc          145
# 204          rwd           front   68.9    55.5         ohc          141
#
#     horsepower  city-mpg  highway-mpg  price
# 0          111        21           27  13495
# 1          111        21           27  16500
# 2          154        19           26  16500
# 3          102        24           30  13950
# 4          115        18           22  17450
# ..         ...       ...          ...    ...
# 200        114        23           28  16845
# 201        160        19           25  19045
# 202        134        18           23  21485
# 203        106        26           27  22470
# 204        114        19           25  22625
#
# [205 rows x 15 columns]

# %%
freq = df['body-style'].value_counts()
names = ['sedan','hatchback','wagon','hardtop','convertible']
plt.pie(freq,labels = names, autopct='%0.0f%%')
plt.show()

# %%
freq
# Out:
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: body-style, dtype: int64

# %%
names
# Out:
# array(['convertible', 'hatchback', 'sedan', 'wagon', 'hardtop'],
#       dtype=object)

# %%
#Pandas piechart

# %%
df['body-style'].value_counts().plot(kind = 'pie', autopct = '%0.0f%%')
# Out:
# <AxesSubplot:ylabel='body-style'>

# %% [markdown]
# # Plotly

# %%
# !pip install plotly

# %%
#histogram

# %%
import plotly.express as pe

# %%
graph = pe.histogram(df['width'])
graph.show()
# Out:
# <div>                            <div id="19489cac-ccee-4ed3-bdf6-fb5f1ba34dba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("19489cac-ccee-4ed3-bdf6-fb5f1ba34dba")) {                    Plotly.newPlot(                        "19489cac-ccee-4ed3-bdf6-fb5f1ba34dba",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"variable=width<br>value=%{x}<br>count=%{y}<extra></extra>","legendgroup":"width","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"width","offsetgroup":"width","orientation":"v","showlegend":true,"x":[64.1,64.1,65.5,66.2,66.4,66.3,71.4,71.4,71.4,67.9,64.8,64.8,64.8,64.8,66.9,66.9,67.9,70.9,60.3,63.6,63.6,63.8,63.8,63.8,63.8,63.8,63.8,63.8,64.6,66.3,63.9,63.9,64.0,64.0,64.0,64.0,63.9,65.2,65.2,65.2,62.5,65.2,66.0,61.8,63.6,63.6,65.2,69.6,69.6,70.6,64.2,64.2,64.2,64.2,64.2,65.7,65.7,65.7,65.7,66.5,66.5,66.5,66.5,66.5,66.5,66.1,66.1,70.3,70.3,70.3,71.7,71.7,70.5,71.7,72.0,68.0,64.4,64.4,64.4,63.8,65.4,65.4,66.3,66.3,66.3,65.4,65.4,65.4,65.4,63.8,63.8,63.8,63.8,63.8,63.8,63.8,63.8,63.8,63.8,65.2,65.2,66.5,66.5,66.5,67.9,67.9,67.9,68.4,68.4,68.4,68.4,68.4,68.4,68.4,68.4,68.4,68.4,68.3,63.8,63.8,63.8,63.8,63.8,64.6,66.3,68.3,65.0,65.0,65.0,72.3,66.5,66.6,66.5,66.5,66.5,66.5,66.5,66.5,63.4,63.6,63.8,65.4,65.4,65.4,65.4,65.4,65.4,65.4,65.4,65.4,63.6,63.6,63.6,63.6,63.6,63.6,64.4,64.4,64.4,64.4,64.4,64.4,64.4,64.0,64.0,64.0,64.0,65.6,65.6,65.6,65.6,65.6,65.6,66.5,66.5,66.5,66.5,66.5,67.7,67.7,66.5,66.5,65.5,65.5,65.5,65.5,65.5,65.5,65.5,64.2,64.0,66.9,66.9,66.9,67.2,67.2,67.2,67.2,67.2,67.2,68.9,68.8,68.9,68.9,68.9],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth ...
